# %% [markdown]
# # Word Embeddings
# In this notebook, we will implement and train word2vec using the Skip-Gram model and word2vec using the CBOW model in TensorFlow. We will also investigate the behavior of pretrained GloVe embeddings models on an analogy task. This notebook is adapted from https://www.tensorflow.org/tutorials/word2vec.

# %% [markdown]
# ## Set Up Helpers

# %%
# %matplotlib inline

import collections
from functools import partial
import math
import os
import random
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange

import tensorflow as tf

# Helper TensorFlow functions
from utils import get_session, maybe_download
# Out:
# /Users/Ched/info/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %% [markdown]
# ## Download Data and Parameters

# %%
maybe_download('http://mattmahoney.net/dc/text8.zip', 'datasets', 31344016)
maybe_download('http://download.tensorflow.org/data/questions-words.txt', 'datasets', 603955)
maybe_download('http://nlp.stanford.edu/data/glove.6B.zip', 'datasets', 862182613)
if not os.path.exists(os.path.join("datasets", "glove.6B.50d.txt")):
    with zipfile.ZipFile(os.path.join("datasets", "glove.6B.zip"), "r") as zip_ref:
        zip_ref.extractall("datasets")
    for f in ["glove.6B.100d.txt", "glove.6B.300d.txt", "glove.6B.200d.txt"]:
        os.remove(os.path.join('datasets', f))
# Out:
# Found and verified datasets/text8.zip
# Found and verified datasets/questions-words.txt
# Found and verified datasets/glove.6B.zip

# %% [markdown]
# ## Setup Up Data

# %%
# Read the data into a list of strings.
def read_vocabulary(filename):
    """Extract the first file enclosed in a zip file as a list of words."""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data

vocabulary = read_vocabulary(os.path.join('datasets', 'text8.zip'))
print('Number of vocabulary items:', len(vocabulary))

# Build the dictionary and replace rare words with UNK token.
vocab_size = 50000

def build_dataset(words, n_words):
    """Process raw inputs into a dataset."""
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(n_words - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        index = dictionary.get(word, 0)
        if index == 0:  # dictionary['UNK']
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reversed_dictionary

# data - list of codes (integers from 0 to vocabulary_size-1).
#   This is the original text but words are replaced by their codes
# count - map of words(strings) to count of occurrences
# dictionary - map of words(strings) to their codes(integers)
# reverse_dictionary - maps codes(integers) to words(strings)
data, count, dictionary, reverse_dictionary = build_dataset(vocabulary, 
                                                            vocab_size)
del vocabulary  # To reduce memory consumption
print('Most common words (+UNK):', count[:5])
print('Sample data:', data[:10], [reverse_dictionary[i] for i in data[:10]])

# %% [markdown]
# # Why use word embeddings?

# %% [markdown]
# A **word embedding** $W: \{1, \dots, N\} \to \mathbb{R}^n$ is a parametric function that maps a word type to a high-dimensional vector. Typically, the function is a simple lookup table parameterized by a matrix $\mathbf{W}$, with a new row for each word type; the query $W(i)$ will return the $i$th row of $\mathbf{W}$. As usual in the machine learning paradigm, $\mathbf{W}$ is initialized randomly, and trained to produce small cost under some objective function.
#
# **What's the motivation for using word embeddings?** We have seen that image processing systems work with complex data encoded as vectors of pixel intensities. On the other hand, traditional NLP systems used to treat words as symbolic tokens. These symbols are arbitrary, and don't provide information about the relationships that may exist between the individual symbols.
#
# To solve these issues, vector space models represent -- or *embed* -- words into a continuous vector space that minimizes distances between semantically similar words.
# Predictive vector space models implement this principle by trying to predict a word from its neighbors (or vice versa) in terms of learned embedding vectors that are considered parameters of the model.
#
# In the following, we investigate some different ways of learning word embeddings.

# %% [markdown]
# # word2vec with NCE
# In classic neural probabilistic  language models (and in tutorial), we use a maximum likelihood criterion to estimate the parameters of a model that computes a vector representation $u_i$ for a word $w_i$ as well as a contextual representation $v_j$ for a history $h_j$ (which could simply be the representation of the preceding word in a unigram model, or a more complex summary of the context). We assume a multinomial distribution over $w_i$, and thus the likelihood objective is a softmax function:
#
# $$\begin{align}
# P(w_i | h_j) &= \frac{\exp \{ u_{i} \cdot v_{j} \} }
#              {\sum_{k=1}^{|\mathcal{V}|} \exp \{ u_{k} \cdot v_{j} \} }~.
#              \tag{1}
# \end{align}$$
#
# **But this is very expensive to compute!** At every timestep $t$ and for each word $w_i$, we need to compute the normalization and sum over words in the vocabulary $\mathcal{V}$, which could be extremely large (often around $10^5$ to $10^7$ terms). Luckily, we can use a method called *noise-contrastive estimation* (NCE) so that we needn't use the full probabilistic model as above, but instead use a binary classification objective. The insight is to try to discriminate the target word $w_i$ from randomly sampled *noise* words $\tilde{w} \sim p_\text{noise}(w)$. The noise distribution $p_\text{noise}(w)$ is often chosen to be the uniform distribution over all words in the vocabulary.
#
# NCE can be shown to approximately maximize the log probability of the full softmax in (1); you can check out the original paper that applied NCE to general unnormalized probability models [1] and or its first application to language modeling [2]. In practice, word embedding training procedures use a slightly modified version of the NCE objective, called *negative sampling* (NS), introduced in [3], in which samples from the noise distribution are strictly *negative* examples (i.e., not $w_i$). Consider the NS objective for a single word-context $w_i$-$h_j$ pair:
#
# $$\ell_\text{NS} (w_i, h_j)
# = - \left[\log p_\theta (D=1 | w_i, h_j) +
#   k \mathop{\mathbb{E}}_{\tilde w \sim p_\text{noise}}
#   \left[ \log p_\theta(D = 0 |\tilde{w}, h_j) \right]\right]~$$
#
# which you can identify as logistic regression applied to the task of distinguishing the target word $w_i$ from draws from the noise distribution $p_\text{noise}(w)$. (For an optional, more in-depth explanation, see [this tutorial](https://lilianweng.github.io/lil-log/2017/10/15/learning-word-embedding.html#noise-contrastive-estimation-nce).)
#
# To compute the NS loss for word2vec, we parameterize a sigmoid function output as follows:
#
# $$% <![CDATA[
# \begin{align}
# p_{U,V} (D=1 | w_i, h_j) &= \sigma({u_{i}} \cdot v_{j}) \\
# p_{U,V} (D = 0 |w_k, h_j) &= 1 - \sigma({u_{k}} \cdot v_{j}) = \sigma(-{u_{k}}\cdot v_{j})
# \end{align} %]]>$$
#
# where $u_i$ and $u_k$ are computed from the target embedding matrix $U$ and $v_{j}$ is computed from the context embedding matrix $V$. The NS loss becomes:
#
# $$- [ \log \sigma({u_i}\cdot v_{j}) +  \sum_{\substack{k=1 \\ w_k \sim p_\text{noise}}}^N \log \sigma(-{u_{k}}\cdot v_{j})]~.\tag{2}$$
#
# **For the word2vec models below, implement the NS objective (2) instead of the full probabilistic model (1).** You will implement the minibatch version that computes the average loss over some number of word-context $w_i$-$h_j$ paris. *Hint*: You may find that using the same batch of noise targets for every element $u_i$ of the target minibatch is sufficient and makes the implementation more efficient.

# %% [markdown]
# ## Q1A. word2vec with CBOW
# First off, we'll consider the Continuous Bag-of-Words (CBOW) model of word embeddings (introduced in Section 3.1 in Mikolov et al.). CBOW predicts a target word from its source context words (for example "in the hat" predicts "cat"). Since the source context is treated as a single observation, CBOW tends to neglect specific cooccurences of word types (in contrast to the Skip-Gram model, as we will discuss later).
#
# **For this question, implement the computational graph that computes the NCE objective for the word2vec CBOW model. Do NOT make use of higher-level primitives from the tf.nn module.**

# %%
cbow_data_index = 0

def generate_batch_cbow(data, batch_size, context_window=1):
    """Generate a batch of examples and targets for use in the CBOW model."""
    global cbow_data_index
    context_size = 2 * context_window
    batch = np.ndarray(shape=(batch_size, context_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * context_window + 1  # [ context_window target context_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[cbow_data_index])
        cbow_data_index = (cbow_data_index + 1) % len(data)
    for i in range(batch_size):
        # context tokens are just all the tokens in buffer except the target
        batch[i, :] = [token for idx, token in enumerate(buffer) if idx != context_window]
        labels[i, 0] = buffer[context_window]
        buffer.append(data[cbow_data_index])
        cbow_data_index = (cbow_data_index + 1) % len(data)
    return batch, labels

def word2vec_cbow(vocab_size, embed_size, num_noise_samples=64, context_size=2, name='word2vec_cbow'):
    
    with tf.variable_scope(name):
        
        train_inputs = tf.placeholder(tf.int32, shape=[None, context_size])
        train_labels = tf.placeholder(tf.int32, shape=[None, 1])
        valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
        
        ### YOUR CODE HERE
        ### Make sure all variable definitions are within the scope!
        ### Implement the NCE loss as a logistic regression objective
        ### that discriminates noise from data samples
        """
        #initialization 
        embeddings = tf.Variable(tf.random_normal([vocab_size,embed_size]))
        
        #sampling 
        index = list(np.random.choice(list(range(vocab_size)),num_noise_samples))
        idx = tf.constant(index)
        sampled_rows = tf.gather(embeddings, idx)
        
        #train embedding
        train_rows = tf.gather(embeddings, train_inputs)
        
        
        
        #raise NotImplementedError("Need to implement the word2vec CBOW objective.")
        """
        #initialization 
        embeddings = tf.Variable(tf.random_normal([vocab_size,embed_size])) #U
        context_embeddings = tf.Variable(tf.random_normal([vocab_size,embed_size]))#V
        inputs = tf.reduce_mean(tf.gather(context_embeddings,train_inputs),axis=1) 
       
        
        biases  = tf.Variable(tf.zeros([vocab_size]))
        loss    = tf.nn.nce_loss(weights=embeddings,biases=biases,labels=train_labels,
                             inputs=inputs,num_sampled=num_noise_samples,num_classes=vocab_size)
        loss = tf.reduce_mean(loss)


      

        ### END YOUR CODE
        ### Your code should instantiate the embeddings and compute the 
        ### loss evaluated on training inputs and labels
        
        norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
        normalized_embeddings = embeddings / norm
        valid_embeddings = tf.gather(normalized_embeddings, valid_dataset)
        valid_similarity = tf.matmul(valid_embeddings, 
                                     normalized_embeddings, transpose_b=True)

    return train_inputs, train_labels, loss, normalized_embeddings, valid_similarity

# %%
np.random.choice(list(range(300)),4)
# Out:
# array([ 66,  17, 211, 241])

# %% [markdown]
# ## Q1B. word2vec with Skip-Grams
# Next up, we'll implement the Skip-Gram model of word embeddings (introduced in Section 3.2 in Mikolov et al.). The approach is algorithmically similar to CBOW; however, since each source context-target pair is treated as a distinct observation, the skip-gram encoding can model more fine-grained information about word cooccurences, and thus is better suited for datasets with infrequent words. However, the model is a little slower to train.
#
# **For this question, implement the computational graph that computes the NCE objective for the word2vec Skip-Gram model. Do NOT make use of higher-level primitives from the tf.nn module.**

# %%
skipgram_data_index = 0

def generate_batch_skipgram(data, batch_size, num_skips=2, skip_window=1):
    """Generate a batch of examples and targets for use in the SkipGram model."""
    global skipgram_data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    if skipgram_data_index + span > len(data):
        skipgram_data_index = 0
    buffer.extend(data[skipgram_data_index:skipgram_data_index + span])
    skipgram_data_index += span
    for i in range(batch_size // num_skips):
        context_words = [w for w in range(span) if w != skip_window]
        words_to_use = random.sample(context_words, num_skips)
        for j, context_word in enumerate(words_to_use):
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[context_word]
        if skipgram_data_index == len(data):
            buffer.extend(data[0:span])
            skipgram_data_index = span
        else:
            buffer.append(data[skipgram_data_index])
            skipgram_data_index += 1
    # Backtrack a little bit to avoid skipping words in the end of a batch
    skipgram_data_index = (skipgram_data_index + len(data) - span) % len(data)
    return batch, labels

def word2vec_skipgram(vocab_size, embed_size, num_noise_samples=64, name='word2vec_skipgram'):
    
    with tf.variable_scope(name):
        
        train_inputs = tf.placeholder(tf.int32, shape=[None])
        train_labels = tf.placeholder(tf.int32, shape=[None, 1])
        valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
        
        ### YOUR CODE HERE
        ### Make sure all variable definitions are within the scope!
        ### Implement the NCE loss as a logistic regression objective
        ### that discriminates noise from data samples
    
        
        embeddings = tf.Variable(tf.random_normal([vocab_size,embed_size]))
        train_embedding = tf.gather(embeddings, train_inputs)
        weights = tf.Variable(tf.random_normal([vocab_size, embed_size]))
        biases  = tf.Variable(tf.zeros([vocab_size]))
        loss    = tf.nn.nce_loss(weights=weights,biases=biases,labels=train_labels,
                             inputs=train_embedding,num_sampled=num_noise_samples,num_classes=vocab_size)
        loss = tf.reduce_mean(loss)
        #raise NotImplementedError("Need to implement the word2vec Skip-Gram objective.")
        
        ### END YOUR CODE
        ### Your code should instantiate the embeddings and compute the 
        ### loss evaluated on training inputs and labels
        
        norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
        normalized_embeddings = embeddings / norm
        valid_embeddings = tf.gather(normalized_embeddings, valid_dataset)
        valid_similarity = tf.matmul(valid_embeddings, 
                                     normalized_embeddings, transpose_b=True)

    return train_inputs, train_labels, loss, normalized_embeddings, valid_similarity

# %% [markdown]
# ## Training
# You can test your implementations by checking if the loss decreases over training, looking at the similarity predictions on the validation set, and also visualizing the t-SNE embedded vectors.

# %%
# Function to draw visualization of distance between embeddings.
def plot_with_labels(low_dim_embs, labels):
    assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
    plt.figure(figsize=(18, 18))  # in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i, :]
        plt.scatter(x, y)
        plt.annotate(
            label,
            xy=(x, y),
            xytext=(5, 2),
            textcoords='offset points',
            ha='right',
            va='bottom')
    plt.show()

def train_embedding_model(train_inputs, 
                          train_labels, 
                          loss, 
                          normalized_embeddings, 
                          validation_similarities, 
                          generate_batch_fn, 
                          num_steps, 
                          cooccurrence_count=None):

    # Construct the SGD optimizer using a learning rate of 1.0
    # You may find that tuning the learning rate is helpful
    optimize_op = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

    # Add variable initializer
    init = tf.global_variables_initializer()

    with get_session() as session:

        init.run()
        print('Initialized the computational graph.')

        average_loss = 0
        for step in xrange(num_steps):

            batch_inputs, batch_labels = generate_batch_fn()
            feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}
                
            # We perform one update step by evaluating the optimizer op (including it
            # in the list of returned values for session.run()
            _, loss_val = session.run([optimize_op, loss], feed_dict=feed_dict)
            average_loss += loss_val

            if step % 2000 == 0:
                if step > 0:
                    average_loss /= 2000
                # The average loss is an estimate of the loss over the last 2000 batches.
                print('Average loss at step ', step, ': ', average_loss)
                average_loss = 0

            # Note that this is expensive! (~20% slowdown if computed every 500 steps)
            if step % 10000 == 0:
                sim = validation_similarities.eval()
                for i in xrange(valid_size):
                    valid_word = reverse_dictionary[valid_examples[i]]
                    top_k = 8  # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                    log_str = 'Nearest to %s:' % valid_word
                    for k in xrange(top_k):
                        close_word = reverse_dictionary[nearest[k]]
                        log_str = '%s %s,' % (log_str, close_word)
                    print(log_str)
              
        # Return the values of the embeddings at the end of training
        return normalized_embeddings.eval()

# %%
# Use this block to train the different models
embed_size = 128       # embedding dimension
batch_size = 64        # number of examples in a minibatch
num_steps = 1000000    # number of minibatches to observe during training

valid_size = 16      # Random set of words to evaluate similarity on.
valid_window = 100   # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)

batch_function_kwargs = {'data': data, 'batch_size': batch_size}

# %%
# Train the CBOW model in this block. Display the output for submission.

train_inputs, train_labels, loss, normalized_embeddings, valid_similarity = word2vec_cbow(vocab_size, embed_size)
generate_batch_fn = partial(generate_batch_cbow, **batch_function_kwargs)

# Call the training loop
final_embeddings = train_embedding_model(train_inputs, 
                                         train_labels, 
                                         loss, 
                                         normalized_embeddings, 
                                         valid_similarity, 
                                         generate_batch_fn, 
                                         num_steps)

try:
    # pylint: disable=g-import-not-at-top
    from sklearn.manifold import TSNE
    import matplotlib.pyplot as plt

    tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
    plot_only = 500
    low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
    labels = [reverse_dictionary[i] for i in xrange(plot_only)]
    plot_with_labels(low_dim_embs, labels)

except ImportError as ex:
    print('Please install sklearn, matplotlib, and scipy to show embeddings.')
    print(ex)
# Out:
# Initialized the computational graph.
# Average loss at step  0 :  369.7343444824219
# Nearest to while: uncanny, parastatal, layman, sepulchre, xxxx, conflicted, usc, electrolytic,
# Nearest to if: macrae, praline, cesar, standstill, gath, reddy, pylons, networked,
# Nearest to seven: reads, lions, jimi, burrito, prompt, offutt, iceni, distilling,
# Nearest to has: bushmen, langle, soaking, tain, combative, ireann, dreadnoughts, stair,
# Nearest to the: comforted, benchmark, puberty, aa, rips, kurdistan, marr, heighten,
# Nearest to its: rewrite, sledge, stylings, chaker, illyricum, certifications, prisoners, castillo,
# Nearest to nine: woodwind, palacio, gollancz, goryeo, revised, weymouth, honduras, dagon,
# Nearest to used: ebenezer, tack, montenegrin, entertainers, fallacy, communions, sons, riddled,
# Nearest to these: cookbook, betray, pettigrew, motorway, fia, obrenovi, taper, mosque,
# Nearest to who: gallurese, bolden, dangerously, accommodated, arabized, bistable, xiong, manuscript,
# Nearest to were: hulme, fayetteville, infrastructural, his, backing, concerned, grigory, goers,
# Nearest to between: bandleaders, memetic, walrus, importantly, malawian, zak, zappa, misinformation,
# Nearest to about: deutsche, producing, penzance, gottlieb, sheeana, fantastically, osmosis, outcome,
# Nearest to new: gallipoli, alcibiades, sings, fujiko, multiply, scramble, anion, nasir,
# Nearest to called: anima, tapestry, contributes, writable, apollonia, honor, rehoboam, yusupov,
# Nearest to to: holism, wishart, somerville, shiloh, mariana, stimulus, misr, clone,
# Average loss at step  2000 :  137.35666951560975
# Average loss at step  4000 :  64.32347264289857
# Average loss at step  6000 :  41.703075438976285
# Average loss at step  8000 :  29.555359862327574
# Average loss at step  10000 :  23.160858353853225
# Nearest to while: agora, colbert, kinematic, manipulative, negotiate, jermaine, observation, ogg,
# Nearest to if: cesar, austro, rice, czechoslovak, monarchies, does, scsi, hester,
# Nearest to seven: eight, five, speculative, realist, gal, parenting, disappear, bugatti,
# Nearest to has: had, have, is, claudius, was, been, switch, canaanite,
# Nearest to the: emb, junkers, an, mathura, injures, hydration, propeller, shogun,
# Nearest to its: their, his, alpina, all, chesterfield, fostered, boulogne, some,
# Nearest to nine: eight, zero, merchandising, sioux, manifest, seven, rfc, nmos,
# Nearest to used: seen, established, called, known, branches, take, made, habitability,
# Nearest to these: strunk, algae, many, all, harlequin, stirred, suppression, servants,
# Nearest to who: they, he, not, been, there, which, assimilate, hepburn,
# Nearest to were: are, is, miniature, have, experiential, akad, by, sobriquet,
# Nearest to between: with, from, analogs, bastion, while, hopi, solidly, ertegun,
# Nearest to about: liberian, launceston, workgroup, mahmoud, hung, wangenheim, fatally, disagreeing,
# Nearest to new: city, first, wg, orestes, ligase, hijackings, root, mimi,
# Nearest to called: also, used, very, document, sheldon, graceland, anthropomorphic, fayette,
# Nearest to to: for, with, separatism, delany, crouch, mika, refering, baikonur,
# Average loss at step  12000 :  19.015525175094606
# Average loss at step  14000 :  16.148699726104738
# Average loss at step  16000 :  13.756873983860016
# Average loss at step  18000 :  12.457872577667237
# Average loss at step  20000 :  11.49954407131672
# Nearest to while: when, where, during, by, after, in, is, although,
# Nearest to if: tabernacle, cathedrals, was, bf, delegates, dhcp, would, khmelnytsky,
# Nearest to seven: four, nine, six, eight, zero, five, arthur, papeete,
# Nearest to has: had, have, was, is, somber, see, would, were,
# Nearest to the: his, its, their, some, this, any, each, her,
# Nearest to its: their, his, the, any, some, this, all, them,
# Nearest to nine: eight, seven, six, four, five, zero, september, shearer,
# Nearest to used: given, found, considered, seen, known, made, still, rot,
# Nearest to these: many, exhorts, calligraphy, authoritarianism, hypothalamus, some, those, they,
# Nearest to who: he, which, been, there, then, they, often, not,
# Nearest to were: are, but, was, would, had, will, is, if,
# Nearest to between: against, with, at, while, during, by, statically, into,
# Nearest to about: telugu, hiding, overloading, umi, tricky, cannae, unbelief, vision,
# Nearest to new: city, times, ligase, small, orestes, mari, ewen, endocytosis,
# Nearest to called: made, very, considered, misinterpreted, generally, there, she, now,
# Nearest to to: would, may, will, by, from, with, is, unforgettable,
# Average loss at step  22000 :  10.983045145630836
# Average loss at step  24000 :  10.366415916442872
# Average loss at step  26000 :  10.05426904606819
# Average loss at step  28000 :  9.137948082566261
# Average loss at step  30000 :  9.243358023643493
# Nearest to while: if, although, became, but, is, when, against, was,
# Nearest to if: though, although, when, while, became, where, because, is,
# Nearest to seven: eight, four, nine, five, six, three, two, zero,
# Nearest to has: had, was, have, is, are, can, became, although,
# Nearest to the: its, some, this, their, any, her, his, many,
# Nearest to its: their, his, her, the, each, some, any, s,
# Nearest to nine: eight, seven, six, four, five, three, births, one,
# Nearest to used: found, considered, known, given, seen, held, available, worked,
# Nearest to these: several, many, some, any, those, all, his, leaky,
# Nearest to who: they, not, there, often, which, he, also, been,
# Nearest to were: are, was, is, although, by, became, while, could,
# Nearest to between: against, on, of, through, during, with, into, after,
# Nearest to about: telugu, severus, ex, selectable, petitioned, jasmuheen, like, bra,
# Nearest to new: city, main, single, small, debasement, of, including, second,
# Nearest to called: considered, sometimes, usually, still, scuderia, now, widely, expression,
# Nearest to to: would, can, will, may, could, into, who, should,
# Average loss at step  32000 :  8.66513811290264
# Average loss at step  34000 :  8.756187968850135
# Average loss at step  36000 :  8.427141798734665
# Average loss at step  38000 :  7.630128404378891
# Average loss at step  40000 :  7.9038499244451526
# Nearest to while: although, though, when, was, is, if, where, before,
# Nearest to if: though, where, when, while, although, since, gaunt, after,
# Nearest to seven: nine, eight, five, six, three, zero, two, one,
# Nearest to has: had, have, was, is, were, became, never, without,
# Nearest to the: her, their, his, its, another, embarrassment, each, them,
# Nearest to its: their, his, any, her, the, some, this, each,
# Nearest to nine: eight, seven, six, five, zero, two, three, one,
# Nearest to used: found, considered, seen, given, held, known, made, possible,
# Nearest to these: many, several, some, the, lewinsky, her, they, various,
# Nearest to who: she, he, they, never, often, still, usually, which,
# Nearest to were: was, are, have, but, while, although, had, being,
# Nearest to between: from, through, in, during, against, into, under, while,
# Nearest to about: christina, until, craters, nhk, selectable, referenced, ltd, bek,
# Nearest to new: old, small, single, city, yury, orestes, at, national,
# Nearest to called: considered, given, generally, now, made, erratic, rot, often,
# Nearest to to: can, will, may, from, in, would, by, for,
# Average loss at step  42000 :  7.630655909895897
# Average loss at step  44000 :  7.594113811016083
# Average loss at step  46000 :  7.583705745697022
# Average loss at step  48000 :  7.146949912428856
# Average loss at step  50000 :  7.2575401018857955
# Nearest to while: however, if, although, though, where, when, before, but,
# Nearest to if: though, although, where, when, but, are, before, while,
# Nearest to seven: eight, six, nine, three, two, zero, five, four,
# Nearest to has: had, have, was, became, is, were, once, having,
# Nearest to the: its, this, his, their, a, s, them, vpi,
# Nearest to its: his, their, her, the, him, our, alpina, them,
# Nearest to nine: eight, six, seven, three, four, five, zero, two,
# Nearest to used: considered, found, seen, given, held, made, written, known,
# Nearest to these: many, some, several, this, part, much, members, both,
# Nearest to who: he, never, there, often, she, still, generally, they,
# Nearest to were: are, was, had, have, is, though, by, became,
# Nearest to between: and, with, against, in, including, through, from, of,
# Nearest to about: following, igg, volcano, segmental, lat, attacks, telemetry, liber,
# Nearest to new: great, national, old, total, main, including, single, original,
# Nearest to called: given, made, considered, generally, still, now, there, irreversible,
# Nearest to to: must, would, can, will, for, could, should, into,
# Average loss at step  52000 :  7.287385420441628
# Average loss at step  54000 :  7.204007022380829
# Average loss at step  56000 :  7.019618450880051
# Average loss at step  58000 :  6.922149551272392
# Average loss at step  60000 :  6.736450424194336
# Nearest to while: although, when, where, if, though, including, since, became,
# Nearest to if: although, when, though, before, where, while, since, could,
# Nearest to seven: nine, eight, six, five, one, three, zero, four,
# Nearest to has: had, have, was, having, is, became, but, once,
# Nearest to the: his, its, their, her, each, a, vpi, our,
# Nearest to its: their, his, her, the, whose, them, our, some,
# Nearest to nine: eight, seven, six, five, three, one, zero, january,
# Nearest to used: found, considered, seen, known, made, held, said, developed,
# Nearest to these: some, many, several, members, those, various, any, each,
# Nearest to who: never, eventually, he, she, still, they, not, ever,
# Nearest to were: are, was, had, is, although, became, if, though,
# Nearest to between: with, against, into, since, from, of, until, and,
# Nearest to about: six, nine, until, around, five, ascendancy, into, seven,
# Nearest to new: great, major, particular, total, city, national, old, single,
# Nearest to called: considered, given, now, scuderia, still, generally, there, usually,
# Nearest to to: will, would, must, should, against, could, from, through,
# Average loss at step  62000 :  6.411214761018753
# Average loss at step  64000 :  6.3967678145170215
# Average loss at step  66000 :  6.780201376914978
# Average loss at step  68000 :  6.643514832735062
# Average loss at step  70000 :  6.368508639454841
# Nearest to while: where, though, although, when, if, among, during, before,
# Nearest to if: though, where, when, although, while, before, are, during,
# Nearest to seven: eight, four, six, nine, three, five, zero, one,
# Nearest to has: had, have, is, having, was, became, but, were,
# Nearest to the: its, his, each, their, a, her, this, another,
# Nearest to its: their, his, her, the, a, whose, our, serpentine,
# Nearest to nine: eight, seven, six, four, three, one, five, april,
# Nearest to used: found, considered, seen, known, written, possible, developed, said,
# Nearest to these: some, many, various, all, those, their, each, several,
# Nearest to who: never, she, they, there, he, still, generally, which,
# Nearest to were: are, was, is, had, though, although, but, have,
# Nearest to between: on, in, against, from, through, until, with, into,
# Nearest to about: until, since, on, following, during, around, over, before,
# Nearest to new: national, single, major, city, great, loan, original, large,
# Nearest to called: considered, given, now, scuderia, created, liquor, deacon, direct,
# Nearest to to: will, must, against, would, should, might, can, into,
# Average loss at step  72000 :  6.3778828760385515
# Average loss at step  74000 :  6.363815503150224
# Average loss at step  76000 :  6.655619866847992
# Average loss at step  78000 :  6.3356736497879025
# Average loss at step  80000 :  6.430854975104332
# Nearest to while: although, when, despite, though, against, during, if, within,
# Nearest to if: though, although, when, before, where, while, but, despite,
# Nearest to seven: five, eight, six, nine, four, three, zero, one,
# Nearest to has: had, have, having, was, is, became, since, although,
# Nearest to the: its, their, his, this, another, any, a, each,
# Nearest to its: his, their, her, the, our, any, my, your,
# Nearest to nine: eight, five, seven, six, three, four, april, zero,
# Nearest to used: seen, known, considered, found, written, given, developed, built,
# Nearest to these: many, several, some, those, various, both, any, they,
# Nearest to who: never, she, he, they, still, generally, there, not,
# Nearest to were: are, was, is, although, by, had, have, being,
# Nearest to between: with, in, during, into, on, against, among, including,
# Nearest to about: nine, following, telemetry, late, early, necessary, metabolised, vegetable,
# Nearest to new: city, endocytosis, main, national, complete, single, same, old,
# Nearest to called: considered, now, given, still, created, used, there, probably,
# Nearest to to: must, should, might, could, would, may, can, will,
# Average loss at step  82000 :  6.2985700426101685
# Average loss at step  84000 :  6.298055627465248
# Average loss at step  86000 :  6.072943801641464
# Average loss at step  88000 :  5.884084421992302
# Average loss at step  90000 :  6.150858130216599
# Nearest to while: when, although, were, during, where, are, though, within,
# Nearest to if: where, when, although, though, since, until, before, so,
# Nearest to seven: eight, six, five, nine, four, three, zero, one,
# Nearest to has: had, have, having, is, was, since, became, were,
# Nearest to the: his, her, its, their, each, this, whose, your,
# Nearest to its: their, her, his, our, the, your, my, them,
# Nearest to nine: eight, seven, six, five, four, three, zero, april,
# Nearest to used: known, seen, found, considered, possible, developed, written, given,
# Nearest to these: some, many, several, all, various, those, both, different,
# Nearest to who: she, never, originally, he, usually, often, they, which,
# Nearest to were: are, although, was, while, is, had, but, have,
# Nearest to between: with, including, within, among, against, in, under, from,
# Nearest to about: following, main, original, last, until, astronomically, same, within,
# Nearest to new: single, particular, great, major, main, traditional, endocytosis, few,
# Nearest to called: considered, used, pederasty, created, developed, scuderia, given, deacon,
# Nearest to to: would, will, must, could, can, might, should, may,
# Average loss at step  92000 :  6.053334257125854
# Average loss at step  94000 :  5.828975075244903
# Average loss at step  96000 :  5.988032625317573
# Average loss at step  98000 :  5.831348515987396
# Average loss at step  100000 :  5.911365544438362
# Nearest to while: although, when, though, during, for, where, in, since,
# Nearest to if: though, when, where, although, like, became, becomes, but,
# Nearest to seven: nine, eight, four, five, six, three, one, zero,
# Nearest to has: had, have, is, was, having, were, since, are,
# Nearest to the: his, its, each, any, their, some, this, whose,
# Nearest to its: their, his, her, our, the, your, any, whose,
# Nearest to nine: eight, seven, four, six, three, one, five, two,
# Nearest to used: found, seen, available, considered, written, known, held, developed,
# Nearest to these: some, many, various, several, they, all, both, those,
# Nearest to who: never, she, he, originally, actually, which, then, there,
# Nearest to were: are, had, have, was, by, being, include, without,
# Nearest to between: with, in, including, from, during, of, among, under,
# Nearest to about: regenerated, until, on, benson, brindle, following, fistula, seven,
# Nearest to new: single, old, city, major, few, main, same, following,
# Nearest to called: considered, scuderia, reset, provided, now, produced, johansen, probably,
# Nearest to to: into, will, for, should, could, must, through, can,
# Average loss at step  102000 :  5.939717609047889
# Average loss at step  104000 :  5.795256821393966
# Average loss at step  106000 :  5.777026872396469
# Average loss at step  108000 :  5.642819887042045
# Average loss at step  110000 :  5.408308773875237
# Nearest to while: where, although, during, when, though, within, like, if,
# Nearest to if: when, though, where, although, while, because, but, say,
# Nearest to seven: six, eight, nine, five, three, four, one, two,
# Nearest to has: had, have, was, is, by, but, were, having,
# Nearest to the: each, their, its, his, this, our, any, some,
# Nearest to its: their, his, our, her, your, any, my, each,
# Nearest to nine: eight, seven, six, five, four, three, one, march,
# Nearest to used: seen, considered, found, available, held, written, known, developed,
# Nearest to these: many, some, several, various, they, all, different, those,
# Nearest to who: she, still, often, he, usually, never, actually, they,
# Nearest to were: are, was, had, include, is, while, although, have,
# Nearest to between: with, in, from, during, among, within, including, on,
# Nearest to about: only, five, since, over, until, nine, four, march,
# Nearest to new: single, city, national, major, few, local, great, small,
# Nearest to called: considered, true, created, probably, given, produced, pederasty, defined,
# Nearest to to: into, can, must, might, would, will, from, through,
# Average loss at step  112000 :  5.4837977694273
# Average loss at step  114000 :  5.565832937002182
# Average loss at step  116000 :  5.615870816469193
# Average loss at step  118000 :  5.461180505275727
# Average loss at step  120000 :  5.4829086176157
# Nearest to while: though, although, during, without, were, after, where, of,
# Nearest to if: when, though, where, although, but, since, because, while,
# Nearest to seven: eight, six, five, three, nine, four, one, zero,
# Nearest to has: had, was, have, having, is, by, once, since,
# Nearest to the: its, their, his, her, each, a, any, our,
# Nearest to its: their, his, her, our, the, your, any, a,
# Nearest to nine: eight, five, seven, six, four, three, zero, january,
# Nearest to used: seen, considered, found, written, known, held, given, available,
# Nearest to these: many, several, some, various, all, different, they, especially,
# Nearest to who: they, she, still, actually, never, usually, there, generally,
# Nearest to were: are, was, is, by, while, but, had, although,
# Nearest to between: within, from, against, with, during, among, under, through,
# Nearest to about: until, on, following, before, tunnels, first, around, only,
# Nearest to new: city, major, great, single, traditional, modern, third, basic,
# Nearest to called: considered, now, created, produced, there, formed, pederasty, developed,
# Nearest to to: must, should, will, would, under, might, into, can,
# Average loss at step  122000 :  5.601344464421272
# Average loss at step  124000 :  5.433493924856186
# Average loss at step  126000 :  5.319235235214234
# Average loss at step  128000 :  5.357254582524299
# Average loss at step  130000 :  5.318468643784523
# Nearest to while: and, though, during, although, through, within, were, among,
# Nearest to if: though, when, although, where, because, makes, became, did,
# Nearest to seven: eight, nine, six, five, four, zero, three, two,
# Nearest to has: had, have, having, is, was, includes, although, makes,
# Nearest to the: its, his, each, any, their, a, our, another,
# Nearest to its: their, his, her, the, our, any, your, some,
# Nearest to nine: eight, seven, six, five, four, births, zero, three,
# Nearest to used: written, seen, considered, found, required, available, developed, known,
# Nearest to these: many, several, some, those, various, different, both, such,
# Nearest to who: he, she, they, actually, never, still, which, it,
# Nearest to were: are, was, by, had, while, have, and, without,
# Nearest to between: with, from, within, among, against, during, through, into,
# Nearest to about: on, tunnels, until, within, over, through, from, around,
# Nearest to new: city, major, great, basic, national, modern, loads, full,
# Nearest to called: considered, produced, now, pederasty, johansen, there, formed, created,
# Nearest to to: would, must, can, through, will, into, should, for,
# Average loss at step  132000 :  5.339841971635819
# Average loss at step  134000 :  5.379544268965721
# Average loss at step  136000 :  5.6686944522857665
# Average loss at step  138000 :  5.3448703225851055
# Average loss at step  140000 :  5.333660441637039
# Nearest to while: when, though, during, although, where, however, among, within,
# Nearest to if: though, when, where, although, because, while, however, is,
# Nearest to seven: nine, eight, six, five, zero, three, four, march,
# Nearest to has: had, have, having, was, since, never, ever, is,
# Nearest to the: its, their, his, each, another, this, any, our,
# Nearest to its: their, his, her, our, the, any, your, each,
# Nearest to nine: eight, seven, six, five, births, zero, march, four,
# Nearest to used: seen, found, written, developed, considered, built, described, required,
# Nearest to these: many, some, several, various, those, other, both, numerous,
# Nearest to who: he, they, she, now, still, actually, never, it,
# Nearest to were: are, was, by, is, have, being, without, had,
# Nearest to between: with, within, among, through, from, including, during, on,
# Nearest to about: following, over, within, through, on, main, from, between,
# Nearest to new: major, city, local, special, third, small, few, national,
# Nearest to called: considered, scuderia, produced, johansen, created, given, now, quite,
# Nearest to to: into, through, must, can, from, will, would, without,
# Average loss at step  142000 :  5.132290299773216
# Average loss at step  144000 :  4.97232123196125
# Average loss at step  146000 :  5.157713029503823
# Average loss at step  148000 :  5.304392594814301
# Average loss at step  150000 :  5.282848902702332
# Nearest to while: although, though, where, within, before, during, when, throughout,
# Nearest to if: when, where, though, although, saw, since, while, however,
# Nearest to seven: eight, six, nine, five, four, zero, three, two,
# Nearest to has: had, have, was, having, is, includes, since, makes,
# Nearest to the: his, its, their, each, our, another, your, her,
# Nearest to its: their, his, her, the, our, your, any, my,
# Nearest to nine: eight, seven, six, five, four, births, march, february,
# Nearest to used: seen, considered, found, written, known, given, described, created,
# Nearest to these: some, many, various, several, those, both, all, types,
# Nearest to who: never, she, he, actually, which, still, there, they,
# Nearest to were: are, was, is, have, by, had, while, although,
# Nearest to between: within, among, with, against, in, through, into, during,
# Nearest to about: on, over, only, within, between, following, approx, latter,
# Nearest to new: national, major, city, few, following, large, local, single,
# Nearest to called: considered, created, pederasty, now, scuderia, quite, johansen, typically,
# Nearest to to: will, against, into, would, through, could, can, must,
# Average loss at step  152000 :  5.305923120379448
# Average loss at step  154000 :  5.234898609399796
# Average loss at step  156000 :  5.216867977261543
# Average loss at step  158000 :  4.919191485524178
# Average loss at step  160000 :  5.069856501698494
# Nearest to while: although, where, within, though, throughout, during, since, when,
# Nearest to if: though, when, although, where, did, is, are, whether,
# Nearest to seven: six, five, eight, nine, four, three, two, zero,
# Nearest to has: had, have, having, is, was, includes, eventually, yet,
# Nearest to the: their, its, his, each, another, our, some, this,
# Nearest to its: their, his, the, her, our, any, some, your,
# Nearest to nine: eight, seven, six, five, four, three, births, two,
# Nearest to used: seen, found, available, required, known, given, considered, written,
# Nearest to these: many, some, several, various, both, numerous, those, other,
# Nearest to who: she, never, he, which, there, it, they, actually,
# Nearest to were: are, was, had, without, is, but, though, although,
# Nearest to between: with, within, among, from, against, in, including, through,
# Nearest to about: around, over, following, latter, main, within, nearly, on,
# Nearest to new: major, following, national, former, old, original, whole, full,
# Nearest to called: considered, johansen, becomes, typically, pederasty, generally, quite, defined,
# Nearest to to: against, should, might, could, will, would, into, cannot,
# Average loss at step  162000 :  5.183239067196846
# Average loss at step  164000 :  4.982116957783699
# Average loss at step  166000 :  5.084991128087044
# Average loss at step  168000 :  5.077708315134048
# Average loss at step  170000 :  5.028127443313599
# Nearest to while: although, though, where, when, before, since, during, against,
# Nearest to if: when, though, although, where, is, whether, while, before,
# Nearest to seven: six, eight, nine, five, four, three, one, two,
# Nearest to has: had, have, was, having, is, since, were, includes,
# Nearest to the: its, his, their, each, our, this, her, another,
# Nearest to its: their, his, the, her, our, my, any, your,
# Nearest to nine: seven, six, eight, five, four, three, births, zero,
# Nearest to used: seen, written, available, found, given, required, considered, described,
# Nearest to these: many, some, several, both, various, different, certain, numerous,
# Nearest to who: she, never, he, already, actually, they, still, it,
# Nearest to were: are, was, had, is, have, while, has, without,
# Nearest to between: in, from, against, with, into, within, and, among,
# Nearest to about: around, overboard, on, within, over, following, main, swirling,
# Nearest to new: major, whole, large, full, single, following, city, old,
# Nearest to called: considered, formed, deacon, quite, defined, actually, becomes, scuderia,
# Nearest to to: into, will, for, against, can, should, from, must,
# Average loss at step  172000 :  5.123092378854752
# Average loss at step  174000 :  5.078211435079575
# Average loss at step  176000 :  4.936492448091507
# Average loss at step  178000 :  4.7693241461515425
# Average loss at step  180000 :  4.939324544906616
# Nearest to while: although, though, when, within, during, through, despite, before,
# Nearest to if: when, though, although, where, unless, while, before, makes,
# Nearest to seven: five, eight, six, nine, four, three, zero, one,
# Nearest to has: had, have, was, is, makes, includes, since, contains,
# Nearest to the: its, each, any, another, their, our, his, a,
# Nearest to its: their, his, her, the, our, any, my, some,
# Nearest to nine: eight, seven, five, six, four, three, december, march,
# Nearest to used: seen, written, found, required, held, available, produced, known,
# Nearest to these: many, some, several, numerous, those, both, various, their,
# Nearest to who: never, she, they, actually, which, still, he, already,
# Nearest to were: are, was, have, had, although, by, while, is,
# Nearest to between: within, with, among, in, from, of, through, into,
# Nearest to about: around, nine, approximately, over, latter, unclear, six, only,
# Nearest to new: major, single, special, specific, old, following, traditional, whole,
# Nearest to called: considered, named, formed, performed, now, produced, graceland, pederasty,
# Nearest to to: must, can, will, would, into, could, might, cannot,
# Average loss at step  182000 :  4.914924097955227
# Average loss at step  184000 :  4.963296219110489
# Average loss at step  186000 :  4.960910026371479
# Average loss at step  188000 :  4.8335798559188845
# Average loss at step  190000 :  4.757886633038521
# Nearest to while: although, though, when, however, where, and, if, before,
# Nearest to if: when, though, where, although, makes, while, unless, saw,
# Nearest to seven: eight, nine, six, four, five, three, zero, births,
# Nearest to has: had, have, was, having, ever, originally, under, is,
# Nearest to the: his, their, its, each, her, this, a, another,
# Nearest to its: their, his, her, our, the, your, some, any,
# Nearest to nine: eight, seven, five, six, four, three, march, february,
# Nearest to used: found, seen, required, written, considered, held, given, available,
# Nearest to these: some, many, several, various, those, certain, both, different,
# Nearest to who: never, she, actually, he, now, already, still, often,
# Nearest to were: are, is, was, had, but, being, have, although,
# Nearest to between: from, with, in, among, through, against, into, until,
# Nearest to about: only, latter, approximately, before, until, around, unclear, madden,
# Nearest to new: old, city, history, major, modern, following, number, former,
# Nearest to called: considered, named, produced, actually, defined, described, used, pederasty,
# Nearest to to: could, would, will, must, should, can, into, might,
# Average loss at step  192000 :  4.2641163709163665
# Average loss at step  194000 :  4.697389380216599
# Average loss at step  196000 :  4.594715706467628
# Average loss at step  198000 :  4.76463004386425
# Average loss at step  200000 :  4.815001540064812
# Nearest to while: though, however, although, where, when, were, are, and,
# Nearest to if: when, though, but, do, did, are, because, however,
# Nearest to seven: six, eight, nine, four, five, three, zero, one,
# Nearest to has: had, have, is, was, having, never, originally, were,
# Nearest to the: their, its, his, her, this, our, each, a,
# Nearest to its: their, his, her, the, our, any, your, whose,
# Nearest to nine: eight, seven, six, four, five, three, births, zero,
# Nearest to used: seen, found, given, required, held, written, available, known,
# Nearest to these: some, many, several, various, certain, numerous, different, those,
# Nearest to who: he, never, she, still, there, they, already, often,
# Nearest to were: are, have, while, had, but, was, has, is,
# Nearest to between: in, from, with, within, through, among, into, against,
# Nearest to about: upon, without, despite, within, latter, until, around, regarding,
# Nearest to new: old, former, national, major, modern, citizen, colonised, following,
# Nearest to called: considered, named, designed, produced, popper, perhaps, described, provided,
# Nearest to to: into, against, will, from, through, for, must, between,
# Average loss at step  202000 :  4.829574597120285
# Average loss at step  204000 :  4.749679208755493
# Average loss at step  206000 :  4.870129948973656
# Average loss at step  208000 :  5.015809536218643
# Average loss at step  210000 :  4.971961015582084
# Nearest to while: although, however, during, when, before, until, though, in,
# Nearest to if: though, when, whether, did, although, unless, where, why,
# Nearest to seven: eight, six, four, five, nine, three, two, zero,
# Nearest to has: had, have, having, was, is, contains, once, includes,
# Nearest to the: its, their, his, each, another, our, this, her,
# Nearest to its: their, his, her, the, our, my, your, any,
# Nearest to nine: eight, seven, six, five, four, three, births, zero,
# Nearest to used: found, written, seen, given, known, considered, held, available,
# Nearest to these: many, some, several, various, those, certain, numerous, different,
# Nearest to who: never, she, he, already, they, which, actually, eventually,
# Nearest to were: are, was, had, is, have, while, but, without,
# Nearest to between: from, in, with, against, into, during, through, among,
# Nearest to about: over, latter, around, story, main, following, approximately, only,
# Nearest to new: former, old, local, major, national, city, main, third,
# Nearest to called: considered, played, pederasty, produced, johansen, named, saw, described,
# Nearest to to: into, will, would, could, against, must, through, should,
# Average loss at step  212000 :  4.840799675703049
# Average loss at step  214000 :  4.6631896288394925
# Average loss at step  216000 :  4.628815566837788
# Average loss at step  218000 :  4.907898697257042
# Average loss at step  220000 :  4.8658883289098736
# Nearest to while: although, though, when, however, where, like, since, were,
# Nearest to if: though, when, where, then, since, becomes, makes, although,
# Nearest to seven: eight, nine, six, five, four, three, births, february,
# Nearest to has: had, have, was, contains, having, is, makes, gives,
# Nearest to the: its, his, their, each, this, any, our, another,
# Nearest to its: their, his, her, our, the, your, any, this,
# Nearest to nine: eight, seven, six, four, five, births, three, zero,
# Nearest to used: written, found, seen, considered, available, known, described, defined,
# Nearest to these: some, many, several, various, both, certain, numerous, those,
# Nearest to who: never, she, he, they, actually, already, still, eventually,
# Nearest to were: are, was, had, by, have, is, although, when,
# Nearest to between: from, with, including, in, within, among, into, during,
# Nearest to about: approximately, reached, latter, resent, overboard, stuff, necessary, around,
# Nearest to new: former, old, local, federal, major, few, special, following,
# Nearest to called: considered, named, pederasty, johansen, heidegger, described, actually, perhaps,
# Nearest to to: must, from, through, should, into, will, cannot, would,
# Average loss at step  222000 :  4.92064293050766
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-7a7beb889faf> in <module>()
#      11                                          valid_similarity,
#      12                                          generate_batch_fn,
# ---> 13                                          num_steps)
#      14
#      15 try:
#
# <ipython-input-8-563eb553dcb2> in train_embedding_model(train_inputs, train_labels, loss, normalized_embeddings, validation_similarities, generate_batch_fn, num_steps, cooccurrence_count)
#      39         for step in xrange(num_steps):
#      40
# ---> 41             batch_inputs, batch_labels = generate_batch_fn()
#      42             feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}
#      43
#
# <ipython-input-15-bb9ec3d07472> in generate_batch_cbow(data, batch_size, context_window)
#      15         # context tokens are just all the tokens in buffer except the target
#      16         batch[i, :] = [token for idx, token in enumerate(buffer) if idx != context_window]
# ---> 17         labels[i, 0] = buffer[context_window]
#      18         buffer.append(data[cbow_data_index])
#      19         cbow_data_index = (cbow_data_index + 1) % len(data)
#
# KeyboardInterrupt:

# %%
# Train the Skip-Gram model in this block. Display the output for submission.

train_inputs, train_labels, loss, normalized_embeddings, valid_similarity = word2vec_skipgram(vocab_size, embed_size)
generate_batch_fn = partial(generate_batch_skipgram, **batch_function_kwargs)

# Call the training loop
final_embeddings = train_embedding_model(train_inputs, 
                                         train_labels, 
                                         loss, 
                                         normalized_embeddings, 
                                         valid_similarity, 
                                         generate_batch_fn, 
                                         num_steps)

try:
    # pylint: disable=g-import-not-at-top
    from sklearn.manifold import TSNE
    import matplotlib.pyplot as plt

    tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
    plot_only = 500
    low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
    labels = [reverse_dictionary[i] for i in xrange(plot_only)]
    plot_with_labels(low_dim_embs, labels)

except ImportError as ex:
    print('Please install sklearn, matplotlib, and scipy to show embeddings.')
    print(ex)

# %% [markdown]
# ## Q1C. Compare CBOW and Skip-Gram
#
# **Did you notices any differences in training or evaluation between these two methods? Give a brief summary below.**

# %% [markdown]
# ### Your written answer here!

# %% [markdown]
# # Part 2: Word Similarity & Analogies with Pretrained Word Embeddings

# %% [markdown]
# **Pretrained word embeddings** are word embeddings that have already been constructed in advance using some (usually task-agnostic) training procedure. The advantage of using off-the-shelf, pretrained word embeddings is that they are computationally simple to use (since no fine-tuning is required). The downside is that they may not be the best for the task we wish to apply them to. We can therefore evaluate the quality of pretrained embeddings by applying them to a specific downstream task such finding the word that is most similar to a given word, or analogical reasoning. The distance (Euclidean or cosine) between two word embeddings should measure the linguistic or semantic similarity of the corresponding words.
#
# Here, we're using GloVe embeddings https://nlp.stanford.edu/projects/glove/ [4].

# %%
import os
import numpy as np
import tensorflow as tf

def load_embeddings(filename):
    vocab = []
    embed = []
    with open(filename, 'r', encoding="utf-8") as f:
        for line in f.readlines():
            row = line.strip().split(' ')
            vocab.append(row[0])
            embed.append(row[1:])
    embed = np.asarray(embed)
    return vocab, embed

def read_analogies(analogy_filepath, word2id):
    questions = []
    with open(analogy_filepath, "r") as analogy_f:
        for line in analogy_f:
            if line.startswith(":"):  # Skip comments.
                continue
            words = line.strip().lower().split(" ")
            ids = [word2id.get(w.strip()) for w in words]
            if not (None in ids or len(ids) != 4):
                questions.append(np.array(ids))
    np.random.shuffle(questions)  # randomize the analogies
    return np.array(questions, dtype=np.int32)

# Load the GloVe vectors into numpy
glove_filepath = os.path.join('datasets', 'glove.6B.50d.txt')
vocab, embed = load_embeddings(glove_filepath)
vocab_size = len(vocab)
embed_dim = len(embed[0])
assert vocab_size > 0, "The vocabulary shouldn't be empty; did you download the GloVe weights?"
print('Loaded %d %d-dimensional embeddings.' % (vocab_size, embed_dim))

word2id = {}
id2word = vocab
for i, w in enumerate(id2word):
    word2id[w] = i

# Load the analogies
analogies = read_analogies(os.path.join('datasets', 'questions-words.txt'), word2id)
assert analogies.shape[0] > 0, "The matrix of analogies shouldn't be empty; did you download the analogies?"
print('Loaded %d analogies.' % analogies.shape[0])

# Ops to load the embeddings into TensorFlow
embedding = tf.Variable(tf.constant(0.0, shape=[vocab_size, embed_dim]),
                        trainable=False, name="embedding")
embedding_placeholder = tf.placeholder(tf.float32, [vocab_size, embed_dim])
embedding_init = embedding.assign(embedding_placeholder)

# %% [markdown]
# ## Q2A. Similar words & antonyms
#
# By learning word embeddings that encode distributional information, we can make use of the principle that *similar words appear in similar contexts*. In paritcular, similar words should have similar embeddings. **Verify this fact by finishing the implementation of a method that find the words with minimum cosine distance to the embedding of a given word in the vocabulary.**
#
# However, one known problem with word embeddings is that antonyms (words with meanings considered to be opposites) often have similar embeddings. You can verify this by searching for an antonym in the top *k* most similar words to a given word. **Find at least 3 such word-antonym pairs with similar embeddings, and give a textual justification for why this occurs in word embedding models.**

# %% [markdown]
# ### Your written answer here!

# %%
def word_pairs(embedding):
    
    target = tf.placeholder(dtype=tf.int32)
    
    ### Find the top most similar words
    ### YOUR CODE HERE
    #normalizing
    embedding = embedding/tf.reshape(tf.norm(embedding,axis=1),(-1,1))
    target_embedding = tf.gather(embedding, target)
    distances = tf.matmul(target_embedding,embedding, transpose_b=True)
    ### END YOUR CODE
    ### ... distances should a vector of size [vocab_size] containing
    ### the distances of the target d to each word in the vocabulary
    
    # Return top 10 as a representative sample
    _, top_k_idx = tf.nn.top_k(distances, 10)
    
    return target, top_k_idx

# %%
# Runtime commands

### Define some target words for which to look up similar words
### YOUR CODE HERE
targets = ['friends','people','france','movies']
### END YOUR CODE

targets = [word2id[target] for target in targets]

with get_session() as sess:
    
    # Initialize the embedding matrix
    sess.run(embedding_init, feed_dict={embedding_placeholder: embed})

    # Create the ops to complete the analogy
    target_placeholder, top_idx = word_pairs(embedding)

    # Complete some analogies!
    for i, target in enumerate(targets):
        idx = sess.run(top_idx, {target_placeholder: [target]})
        print("Word #%d: %s" % (i + 1, target))
        print("\t%s" % ', '.join([id2word[j] for j in idx[0]]))
        print('')

# %% [markdown]
# ## Q2B. Solving the analogy task
#
#
# The analogy task that makes use of the  is as follows: Given a triplet of words $w_a$, $w_b$ and $w_c$, select the appropriate word $w_d$ to complete the following analogy:
#
# <center>$w_a$ is to $w_b$ as $w_c$ is to ???.</center>
#
# An example task woud be is: "Man is to woman as king is to ???"; the correct answer is "queen". Mikolov et al. [2013a] proposed that simple algebraic operations could be applied to vector space embeddings to solve such an analogy task. For $w_d$ that completes the analogy, we expect that
#
# $$v_{w_b} - v_{w_a} \approx v_{w_d} - v_{w_c}$$
#
# i.e., that *the difference between $w_b$ and $w_a$ is similar to the difference between $w_d$ and $w_c$*. The $w_d$ that we would like is therefore
#
# $$v_{w_d} = \arg \max_{w_d \in \mathcal{V} \setminus \{w_a, w_b, w_c\}}
# \cos \left(v_{w_d}, v_{w_b} - v_{w_a} + v_{w_c}\right)~. \tag{3}$$
#
# For this question, implement the analogy prediction method described in (3) by completing the skeleton below.

# %%
def complete_analogy(embedding):
    
    a = tf.placeholder(dtype=tf.int32)
    b = tf.placeholder(dtype=tf.int32)
    c = tf.placeholder(dtype=tf.int32)
    
    ### We need to use the embeddings to solve the analogy task
    ### "a is to b as c is to d"
    ### for d (given a, b, and c)
    ### YOUR CODE HERE
    #normalizing
    embedding = embedding/tf.reshape(tf.norm(embedding,axis=1),(-1,1))
    a_emb = tf.gather(embedding,a)
    b_emb = tf.gather(embedding,b)
    c_emb = tf.gather(embedding,c)
    d_emb = b_emb - a_emb + c_emb
    distances = tf.matmul(d_emb,embedding, transpose_b=True)
    ### END YOUR CODE
    ### ... distances should a vector of size [vocab_size] containing
    ### the distances of the target d to each word in the vocabulary
    
    # Return top 4 in case we accidentally predict a, b or c
    _, top_k_idx = tf.nn.top_k(distances, 4)
    
    return a, b, c, top_k_idx

# %%
# Runtime commands
with get_session() as sess:
    
    # Initialize the embedding matrix
    sess.run(embedding_init, feed_dict={embedding_placeholder: embed})

    # Create the ops to complete the analogy
    a_placeholder, b_placeholder, c_placeholder, top_idx = complete_analogy(embedding)

    # Complete some analogies!
    for i in range(10):
        w0, w1, w2, w3 = analogies[i]
        idx, = sess.run(top_idx, {
            a_placeholder: [w0],
            b_placeholder: [w1],
            c_placeholder: [w2]
        })
        a, b, c, d = [id2word[j] for j in [w0, w1, w2, w3]]
        print("Analogy #%d:" % (i + 1))
        for d_hat in [id2word[j] for j in idx]:
            if d_hat not in [a, b, c]:
                print('\t%s is to %s as %s is to %s\t(ground truth: %s)' % (a, b, c, d_hat, d))
                print('')
                break

# %% [markdown]
# # References
# [1] Gutmann, Michael, and Aapo Hyvärinen. "Noise-contrastive estimation: A new estimation principle for unnormalized statistical models." In Proceedings of the Thirteenth International Conference on Artificial Intelligence and Statistics, pp. 297-304. 2010. http://proceedings.mlr.press/v9/gutmann10a.html
#
# [2] Mnih, Andriy, and Yee Whye Teh. "A fast and simple algorithm for training neural probabilistic language models." In Proceedings of the 29th International Conference
# on Machine Learning, Edinburgh, Scotland, UK, 2012. https://arxiv.org/abs/1206.6426
#
# [3] Mikolov, Tomas, Ilya Sutskever, Kai Chen, Greg S. Corrado, and Jeff Dean. "Distributed representations of words and phrases and their compositionality." In Advances in neural information processing systems, pp. 3111-3119. 2013.
#
# [4] Pennington, Jeffrey, Richard Socher, and Christopher Manning. "Glove: Global vectors for word representation." In Proceedings of the 2014 conference on empirical methods in natural language processing (EMNLP), pp. 1532-1543. 2014.
